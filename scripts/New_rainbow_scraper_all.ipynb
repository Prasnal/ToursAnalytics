# %%
import requests
# trip_type = 'objazd'

def get_trip_list(trip_type, page, limit):
    json_data = {
        'AtrybutyMulti': {
            'TypyWyjazdu': [
                trip_type
            ],
            'Lokalizacje_HoteloProdukt': [],
            'Miasta': [],
        },
        'AtrybutySingle': {
            'DlugoscPobytu': [
                '*-*',
            ],
            'Cena': [
                'avg',
            ],
            'OcenaKlientow': [
                '*-*',
            ],
            'OdlegloscLotnisko': [
                '*-*',
            ],
        },
        'DatyUrodzenia': [
            '1993-01-01',
            '1993-01-01',
        ],
        'LiczbaPokoi': 1,
        'Sortowanie': 'cena-asc',
        'CzyWeekendowka': False,
        'PowrotNaInneLotnisko': False,
        'Strona': page,
        'Limit': limit,
    }


    response = requests.post('https://r.pl/api/wyszukiwarka/wyszukaj', json=json_data)
    return response
#print(len(response.json()['Wynik']))

def merge_trips():
    page_number = 0
    count_wynik = 1
    results = list()
    while count_wynik > 0:
        page_number+=1
        response = get_trip_list('objazd', page_number, limit=10)
        result = response.json()['Wynik']
        count_wynik = len(result)
        results.extend(result)
    return results

# %%
response.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 response.json()
#
# NameError: name 'response' is not defined

# %%
def get_prices(hotel_url, produkt_url):
    json_data = {
    'HotelUrl': hotel_url, #'zakwaterowanie-prg',
    'ProduktUrl': produkt_url, #'praga-express',
    'DatyUrodzenia': [
        '1993-01-01',
        '1993-01-01',
    ],
    #'Wyzywienie': 'sniadania',
    'CzyV2': True,
}

    response = requests.post('https://r.pl/api/wyszukiwarka/wyszukaj-kalkulator',  json=json_data)
    return response.json()


def get_trip_details(trip_id, price, price_without_promo, params):
    data = {
    'Parametry': [
        {
            'Id': trip_id,
            'Cena': price,
            'CenaBezPromocji': price_without_promo,
            'CenyZaOsoby': [
                {},
                {},
            ],
            'Params': params,
        },        
    ],
    'CzyCenaZaOsobe': True,
    'DatyUrodzenia': [
        '1993-01-01',
        '1993-01-01',
    ],
    'LiczbaPokoi': 1,
    'Route': '/wycieczki-objazdowe',
}
    
    response = requests.post('https://r.pl/api/bloczki/pobierz-bloczki',   json=data)
    print(response.text)
    return response.json() #TODO: check if response is correct


def get_product_url():
    pass

def get_hotel_url():
    pass

# %%
results = merge_trips()


for obj in results:
    print(obj)
    trip_id=obj['Id']
    price=obj['Cena']
    price_without_promo=obj['CenaBezPromocji']
    params=obj['Params']
    result = get_trip_details(trip_id, price, price_without_promo, params)
    print(result)
    print()
    print()

    #TODO: save in file togheter with prices
# Out:
# {'Id': '371_8824:159427:6392788', 'Cena': 504, 'CenaBezPromocji': 504, 'CenyZaOsoby': [{'Pokoj': 1, 'Cena': 503}, {'Pokoj': 1, 'Cena': 503}], 'Params': 'sniadania+orzesze+orzesze+-', 'KategoriaWycieczki': 'objazd'}
# ...

# %%
requests.get(url='https://r.pl/po-drugiej-stronie-ziemi/zakwaterowanie-aun').text
# Out:
# '<!DOCTYPE html>\n<html lang="pl">\n<head><meta charset="utf-8">\n<title>Po drugiej stronie Ziemi - Australia, Nowa Zelandia | wycieczki objazdowe z R.pl</title>\n<meta name="app-meta" data-service="rpl-core" data-version="1.23.6">\n<script>\n    window.dataLayer = window.dataLayer || [];\n    function gtag(){dataLayer.push(arguments);}\n\n    gtag(\'consent\', \'default\', {\n    \'ad_storage\': \'denied\',\n    \'analytics_storage\': \'denied\',\n    \'wait_for_update\': 2000\n    });\n\n    dataLayer.push({\n    \'event\': \'default_consent\'\n    });\n</script>\n<script async="" src="https://eured.quietyellowday.com/sxp/i/5979cb9c1d205bfe3b1922d0659e6e14.js" data-ch="cheq4pp" class="ct_clicktrue_21562"></script>\n<script type="application/ld+json">{"@context":"https://schema.org/","@type":"Organization","@id":"https://r.pl/","url":"https://r.pl/","logo":"https://static.r.pl/rpl-cdn/images/icons/r-logo.SVG?v=0","legalName":"Rainbow","name":"Rainbow","description":"Biuro podróży Ra
# ...

# %%
requests.get(url='https://r.pl/api/routing/czy-jest-route?route=%2Fpraga-express%2Fzakwaterowanie-prg').text
# Out:
# '{"Klucz":"praga-express-zakwaterowanie-prg","Route":"/praga-express/zakwaterowanie-prg","Tytul":"Praga Express","PrzekierujNaNowaRpl":true,"CzySilentRefresh":false,"Meta":{"Title":"Praga Express - Czechy | wycieczki objazdowe z R.pl","Description":"Wycieczki objazdowe z R.pl - Praska starówka, Hradczany i królewski zamek • barokowa dzielnica - „Mala Strana” • rejs statkiem z obiadokolacją • przejazd do Pragi w trakcie dnia • Biblioteka Strahovska • Kaplica Betlejemska i dom Jana Husa"},"SekcjaCache":{"Klucz":"karta-hotelu","Cache":300,"CzyTypKategoria":false},"Breadcrumbs":[{"Nazwa":"Rainbow","Url":"/"},{"Nazwa":"Praga Express","Url":"/praga-express"},{"Nazwa":"Zakwaterowanie PRG","Url":"/praga-express/zakwaterowanie-prg"}],"Seo":{"PanstwoUrl":"","RegionUrl":"","PelneSeo":false,"SlowaKluczowe":null},"Filtr":{"CzyWeekendowka":false},"Sitemapa":{"Priorytet":0.7,"Czestotliwosc":"hourly","ModyfikujCo":172800000000000,"Ukryj":false,"Index":true,"Follow":true},"Ingress":{"Nazwa":"Nuxt 3 C
# ...

# %%
'''
curl 'https://r.pl/api/wyszukiwarka/wyszukaj-kalkulator' -X POST -H 'User-Agent: Mozilla/5.0 (X11; Linux x86_64; rv:109.0) Gecko/20100101 Firefox/113.0' -H 'Accept: application/json' -H 'Accept-Language: en-US,en;q=0.5' -H 'Accept-Encoding: gzip, deflate, br' -H 'Referer: https://r.pl/praga-express/zakwaterowanie-prg?czyCenaZaWszystkich=0&data=20240920&dlugoscPobytu=4&iataWyjazdu=katowice&liczbaPokoi=1&miastoWyjazdu=katowice&wiek=1993-01-01&wiek=1993-01-01&wyzywienie=sniadania' -H 'content-type: application/json' -H 'Origin: https://r.pl' -H 'Connection: keep-alive' -H 'Cookie: _ga=GA1.1.1927725096.1661844482; _ga_WT1WJDXNXP=GS1.1.1693576250.10.1.1693576256.0.0.0; _ga_HQWQ6
CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; _gac_UA-1128136-9=1.1691570723.EAIaIQobChMIwcG3h5fPgAMVjE4ZCh3zBQboEAEYASAAEgL2JfD_BwE; _gac_UA-1128136-2=1.1691827751.CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; _gac_UA-1128136-14=1.1691827751.CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; _gcl_aw=GCL.1691827750.CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; _gcl_dc=GCL.1691827750.CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; FPGCLAW=GCL.1691827750.CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; FPGCLDC=GCL.1691827750.CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; KlientIdSchowek=74cd20f7-4aa3-4d6d-bf8b-eab4d7882c8f; BHTGuid=f87e1e65-04cd-46bf-8723-c90b8ce30a57; smPopupFormShowOnVisitCnt=29; _hjid=dd448bb1-e242-4edc-9060-b911718dcd4d; _tt_enable_cookie=1; _ttp=8eA3gJ31doebOrnNO7DnDf9hsHT; _cq_suid=1.1695313799.CQB0V4ZSXK5Qopa5; liczbaPokoi=1; dowolnaLiczbaPokoi=false; wiek=%5B%221993-01-01T12%3A00%3A00.000Z%22%2C%221993-01-01T12%3A00%3A00.000Z%22%5D; _hjHasCachedUserAttributes=true; _clsk=mkyw5i|1695378403137|32|1|u.clarity.ms/collect; smOTimePopCap=popupForm:1695313832785|; fonce_current_session=1; sessionID=wu3j8q; _hjIncludedInSessionSample_1823437=0; _hjSession_1823437=eyJpZCI6ImIwZWMxOTczLWI3ODEtNGYzZS1hZjZhLWQ4OWQ5NjAzM2ViMiIsImNyZWF0ZWQiOjE2OTUzNzYyNTIzNzcsImluU2FtcGxlIjpmYWxzZX0=; _hjAbsoluteSessionInProgress=0; _uetsid=1cc18db0589c11ee8881c91c3e9d2248; _uetvid=b35ae420288311ed91307d582460ba09' -H 'Sec-Fetch-Dest: empty' -H 'Sec-Fetch-Mode: cors' -H 'Sec-Fetch-Site: same-origin' --data-raw '{"HotelUrl":"zakwaterowanie-prg","ProduktUrl":"praga-express","LiczbaPokoi":1,"Dlugosc":4,"TerminWyjazdu":"2024-09-20","Iata":"czestochowa","DatyUrodzenia":["1993-01-01","1993-01-01"],"Wyzywienie":"sniadania","CzyV2":true}'
'''

'''
curl 'https://r.pl/api/wyszukiwarka/wyszukaj-kalkulator' -X POST -H 'User-Agent: Mozilla/5.0 (X11; Linux x86_64; rv:109.0) Gecko/20100101 Firefox/113.0' -H 'Accept: application/json' -H 'Accept-Language: en-US,en;q=0.5' -H 'Accept-Encoding: gzip, deflate, br' -H 'Referer: https://r.pl/kos-wczasy/corali?czyCenaZaWszystkich=0&data=2023-10-03&dlugoscPobytu=5&iataWyjazdu=WAW&liczbaPokoi=1&miastoWyjazdu=katowice&wiek=1993-01-01&wiek=1993-01-01&wyzywienie=2-posilki&wybranePokoje={%222%22:1}' -H 'content-type: application/json' -H 'Origin: https://r.pl' -H 'Connection: keep-alive' -H 'Cookie: _ga=GA1.1.1927725096.1661844482
ALIRJiSQoBAcJaFFABACA2sIIICAEAQAAAAAAAAFwBBCAAAgBBAAAAAAAAAIABAAABAAAAAAAAAAAAAAAAAAhAAAAAAAAAAhAAAAgAAgAAAAAAAAAAAAAAAAAAAgA; _gcl_au=1.1.489429093.1691570684; FPAU=1.2.196102865.1691570685; _fbp=fb.1.1691570685109.17224593; _clck=1gizayu|2|ff8|0|1316; _gac_UA-1128136-8=1.1691827751.CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; _gac_UA-1128136-9=1.1691570723.EAIaIQobChMIwcG3h5fPgAMVjE4ZCh3zBQboEAEYASAAEgL2JfD_BwE; _gac_UA-1128136-2=1.1691827751.CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; _gac_UA-1128136-14=1.1691827751.CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; _gcl_aw=GCL.1691827750.CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; _gcl_dc=GCL.1691827750.CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; FPGCLAW=GCL.1691827750.CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; FPGCLDC=GCL.1691827750.CjwKCAjw29ymBhAKEiwAHJbJ8vVFBL3JqmRZC3-nGPTLkDPSmYHRWHhUtDXo7XaOJWsAsUUbhST-zBoC_c4QAvD_BwE; KlientIdSchowek=74cd20f7-4aa3-4d6d-bf8b-eab4d7882c8f; BHTGuid=f87e1e65-04cd-46bf-8723-c90b8ce30a57; smPopupFormShowOnVisitCnt=29; _hjid=dd448bb1-e242-4edc-9060-b911718dcd4d; _tt_enable_cookie=1; _ttp=8eA3gJ31doebOrnNO7DnDf9hsHT; _cq_suid=1.1695313799.CQB0V4ZSXK5Qopa5; liczbaPokoi=1; dowolnaLiczbaPokoi=false; wiek=%5B%221993-01-01T00%3A00%3A00.000Z%22%2C%221993-01-01T00%3A00%3A00.000Z%22%5D; _hjHasCachedUserAttributes=true; _clsk=mkyw5i|1695380967338|46|1|u.clarity.ms/collect; smOTimePopCap=popupForm:1695313832785|; fonce_current_session=1; sessionID=wu3j8q; _hjIncludedInSessionSample_1823437=0; _hjSession_1823437=eyJpZCI6ImIwZWMxOTczLWI3ODEtNGYzZS1hZjZhLWQ4OWQ5NjAzM2ViMiIsImNyZWF0ZWQiOjE2OTUzNzYyNTIzNzcsImluU2FtcGxlIjpmYWxzZX0=; _hjAbsoluteSessionInProgress=0; _uetsid=1cc18db0589c11ee8881c91c3e9d2248; _uetvid=b35ae420288311ed91307d582460ba09' -H 'Sec-Fetch-Dest: empty' -H 'Sec-Fetch-Mode: cors' -H 'Sec-Fetch-Site: same-origin' --data-raw '{"HotelUrl":"corali","ProduktUrl":"kos-wczasy","LiczbaPokoi":1,"Dlugosc":5,"TerminWyjazdu":"2023-10-03","Iata":"KTW","DatyUrodzenia":["1993-01-01","1993-01-01"],"Wyzywienie":"2-posilki","CzyV2":true}'
'''

json_data = {
    'HotelUrl': 'corali', #'zakwaterowanie-prg',
    'ProduktUrl': 'kos-wczasy', #'praga-express',
    #'LiczbaPokoi': 1,
    #'Dlugosc': 4,
    #'TerminWyjazdu': '2024-09-20',
    #'Iata': 'czestochowa',
    'DatyUrodzenia': [
        '1993-01-01',
        '1993-01-01',
    ],
    #'Wyzywienie': 'sniadania',
    'CzyV2': True,
}

response = requests.post('https://r.pl/api/wyszukiwarka/wyszukaj-kalkulator',  json=json_data)

print(response.text)
#import json
#print(json.dumps(response.text,indent=2))
print()
print()
print(get_trip_details("6033_8752:156130:7353188", 10, 10, "a")) #last minute w fiszkach
# Out:
# {"CzyIstniejeWycieczka":true,"KluczProduktoHotel":"6033_8752","Wybrana":{"Klucz":"6033_8752:156129:7353127","ImprezaId":156129,"HotelWCId":7353127,"RezerwujParametry":"?kodWycieczki=KOS\u0026przystanekWyjazdowyId=774530\u0026przystanekPowrotnyId=755931\u0026wybraneWyzywienie=2-posilki\u0026hotelId=6033\u0026dataStart=2023-09-30\u0026liczbaDoroslych=2\u0026liczbaDzieci=0\u0026liczbaNocy1=3\u0026hotelParams=1_6033_3","Cena":3914,"CenaZaOsobe":1957,"CenaZaliczka":0,"CenaBezPromocji":3914,"CenaBezPromocjiZaOsobe":1957,"CenyZaOsoby":[{"Pokoj":1,"Cena":1956},{"Pokoj":1,"Cena":1956}],"CenyZaWszystkieOsoby":[[{"Pokoj":1,"Cena":1956},{"Pokoj":1,"Cena":1956}]],"Pokoje":"","LiczbaPokoi":1,"IataWyjazdowa":"KTW","IataPowrotna":"KTW","HotelPrzedluzonyId":null,"HotelPrzedluzonyWCId":null,"PodstawowyHotelWCId2":null,"CzyObowiazkowy":false,"Params":"2-posilki+KTW+KTW+-","KluczOmnibus":"7353127_0_1_0_K13_13_I0k_Kk_278757_774530_269469_755931_2-posilki_","PromocjeUrl":[""]},"DatyUrodzenia":["1993-01-01
# ...

# %%
# Out:
# [{"BloczekId":"6033_8752:156130:7353188","BazoweInformacje":{"ImprezaID":156130,"HotelID":6033,"LiczbaDni":5,"LiczbaNocy":4,"LiczbaDniPrzedluzenie":0,"KluczProduktHotel":"6033_8752","KodProduktu":"KOS","TypWycieczki":"wypoczynek","Lokalizacje":"Grecja: Kos","Panstwa":["Grecja"],"Regiony":["Kos"],"GwiazdkiHotelu":4,"NazwaHoteluWWW":"Corali","OfertaNazwa":"Corali","OfertaURL":"/kos-wczasy/corali?data=20231003\u0026dlugoscPobytu=5\u0026miastoWyjazdu=\u0026iataWyjazdu=\u0026wyzywienie=\u0026liczbaPokoi=1\u0026czyCenaZaWszystkich=0\u0026wiek=1993-01-01\u0026wiek=1993-01-01","OfertaBezTerminu":"/kos-wczasy/corali?data=%s\u0026dlugoscPobytu=%d\u0026miastoWyjazdu=%s\u0026iataWyjazdu=%s\u0026wyzywienie=%s\u0026liczbaPokoi=%d\u0026czyCenaZaWszystkich=%d","OfertaURLDlaGoogle":"/kos-wczasy/corali","DatyUrodzenia":["1993-01-01","1993-01-01"],"LiczbaPokoi":1,"Params":"a","HappyHoursKolejnosc":1000},"Zdjecia":["https://zdjecia-cdn.r.pl/hotel/6033/corali_6033_166531_3x2.jpg","https://zdjecia-cdn.r.p
# ...
